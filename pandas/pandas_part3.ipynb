# %%
import pandas as pd

# %%
df =pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # can we extract name column with 2 to 4 indexes names

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][2:5].tolist()
# Out:
# ['Heikkinen, Miss. Laina',
#  'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#  'Allen, Mr. William Henry']

# %%
df[df['Name'].isin(df['Name'][2:5].tolist())]
# Out:
#    PassengerId  Survived  Pclass  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket    Fare Cabin Embarked
# 2  STON/O2. 3101282   7.925   NaN        S
# 3            113803  53.100  C123        S
# 4            373450   8.050   NaN        S

# %% [markdown]
# # list to series conv

# %%
a=[1,2,3]

# %%
pd.Series(a)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# # series to list

# %%
s=pd.Series(a)

# %%
list(s)
# Out:
# [1, 2, 3]

# %% [markdown]
# # change index manually

# %%
df['Name'][0:4]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Name: Name, dtype: object

# %% [markdown]
# - since, it is already having index, it will try to override and nullify the data
# - so we have to convert it to list

# %%
pd.Series(df['Name'][0:4],index=['a','b','c','d'])
# Out:
# a    NaN
# b    NaN
# c    NaN
# d    NaN
# Name: Name, dtype: object

# %%
pd.Series(list(df['Name'][0:4]),index=['a','b','c','d'])
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# dtype: object

# %% [markdown]
# # series append

# %%
s=pd.Series(list(df['Name'][0:4]),index=['a','b','c','d'])

# %%
s1 = df['Name'][5:7]

# %%
s2 = s1.append(s)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3296\2451741888.py in ?()
# ----> 1 s2 = s1.append(s)
#
# C:\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'append'

# %%
s3 = pd.concat([s,s1],axis=0)

# %%
s3
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# dtype: object

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# # drop col

# %%
df.drop(['PassengerId'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # drop row

# %%
df.drop(3,axis=0)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 4           0       3                           Allen, Mr. William Henry
# 5           0       3                                   Moran, Mr. James
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # set any column as index

# %%
df.set_index('Name')
# Out:
#                                                     Survived  Pclass     Sex  \
# Name
# Braund, Mr. Owen Harris                                    0       3    male
# Cumings, Mrs. John Bradley (Florence Briggs Tha...         1       1  female
# Heikkinen, Miss. Laina                                     1       3  female
# Futrelle, Mrs. Jacques Heath (Lily May Peel)               1       1  female
# Allen, Mr. William Henry                                   0       3    male
# ...                                                      ...     ...     ...
# Montvila, Rev. Juozas                                      0       2    male
# Graham, Miss. Margaret Edith                               1       1  female
# Johnston, Miss. Catherine Helen "Carrie"                   0       3  female
# Behr, Mr. Karl Howell                                      1       1    male
# Dooley, Mr. Patrick                                        0       3    male
#
# ...

# %%
df.iloc[3]
# Out:
# Survived                                               1
# Pclass                                                 1
# Name        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                               female
# Age                                                 35.0
# SibSp                                                  1
# Parch                                                  0
# Ticket                                            113803
# Fare                                                53.1
# Cabin                                               C123
# Embarked                                               S
# Name: 3, dtype: object

# %% [markdown]
# # reset index

# %%
df.reset_index()
# Out:
#      index  Survived  Pclass  \
# 0        0         0       3
# 1        1         1       1
# 2        2         1       3
# 3        3         1       1
# 4        4         0       3
# ..     ...       ...     ...
# 886    886         0       2
# 887    887         1       1
# 888    888         0       3
# 889    889         1       1
# 890    890         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # dict operations

# %%
d = {"key1":[1,2,3],
    'key2':[4,5,6],
     'key3':[7,8,9]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
d1 = {"key1":[1,2,3,4],
    'key2':[4,5,6],
     'key3':[7,8,9]}

# %%
pd.DataFrame(d1) # alla arrays should of same lenght
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 pd.DataFrame(d1) # alla arrays should of same lenght
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:736, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     730     mgr = self._init_mgr(
#     731         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     732     )
#     734 elif isinstance(data, dict):
#     735     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 736     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     737 elif isinstance(data, ma.MaskedArray):
#     738     from numpy.ma import mrecords
#
# File C:\Python311\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
# ...

# %% [markdown]
# - tuples

# %%
d = {"key1":(1,2,3),
    'key2':(4,5,6),
     'key3':(7,8,9)}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %% [markdown]
# # null operations

# %%
pwd
# Out:
# 'C:\\Users\\KeerthanaMerugu\\Python\\pandas'

# %%
df1=pd.read_csv('taxonomy.csv.xls')

# %%
df1.head()
# Out:
#   taxonomy_id                     name parent_id     parent_name
# 0         101                Emergency       NaN             NaN
# 1      101-01        Disaster Response       101       Emergency
# 2      101-02           Emergency Cash       101       Emergency
# 3   101-02-01        Help Pay for Food    101-02  Emergency Cash
# 4   101-02-02  Help Pay for Healthcare    101-02  Emergency Cash

# %%
df1.columns
# Out:
# Index(['taxonomy_id', 'name', 'parent_id', 'parent_name'], dtype='object')

# %%
df1['taxonomy_id']
# Out:
# 0            101
# 1         101-01
# 2         101-02
# 3      101-02-01
# 4      101-02-02
#          ...
# 285    111-01-07
# 286       111-02
# 287       111-03
# 288       111-04
# 289       111-05
# Name: taxonomy_id, Length: 290, dtype: object

# %% [markdown]
# ## dropna
# - default axis=0 -- rows
# - axis =col
# - it will drop complete row for having one or more nan

# %%
df1.shape
# Out:
# (290, 4)

# %%
df1.dropna()
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# 5     101-02-03          Help Pay for Housing    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [279 rows x 4 columns]

# %%
290-279
# Out:
# 11

# %% [markdown]
# - only below 2 columns r not hving nan values

# %%
df1.dropna(axis=1)
# Out:
#     taxonomy_id                          name
# 0           101                     Emergency
# 1        101-01             Disaster Response
# 2        101-02                Emergency Cash
# 3     101-02-01             Help Pay for Food
# 4     101-02-02       Help Pay for Healthcare
# ..          ...                           ...
# 285   111-01-07              Workplace Rights
# 286      111-02                     Mediation
# 287      111-03                        Notary
# 288      111-04                Representation
# 289      111-05  Translation & Interpretation
#
# [290 rows x 2 columns]

# %% [markdown]
# # fillna

# %%
df1.fillna('kee')
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       kee                   kee
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %% [markdown]
# # titanic dataset

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## groupby

# %% [markdown]
# - it will similar groups together
# - below Survived column -> it brings '0' together and as well as 1

# %% [markdown]
# - avg pay of survived o and 1

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes[df.dtypes=='int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df.groupby('Survived')[df.dtypes[df.dtypes=='int64'].index].mean()
# Out:
#           PassengerId  Survived    Pclass     SibSp     Parch
# Survived
# 0          447.016393       0.0  2.531876  0.553734  0.329690
# 1          444.368421       1.0  1.950292  0.473684  0.464912

# %%
df.groupby('Survived')[df.dtypes[df.dtypes=='int64'].index].sum()
# Out:
#           PassengerId  Survived  Pclass  SibSp  Parch
# Survived
# 0              245412         0    1390    304    181
# 1              151974       342     667    162    159

# %% [markdown]
# - revenue from female passenger

# %%
df3=df.groupby('Sex')[df.dtypes[df.dtypes=='float64'].index].sum()

# %% [markdown]
# # df rotate

# %%
df3
# Out:
#              Age        Fare
# Sex
# female   7286.00  13966.6628
# male    13919.17  14727.2865

# %%
df3.T
# Out:
# Sex       female        male
# Age    7286.0000  13919.1700
# Fare  13966.6628  14727.2865

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df11  = df[['Name','Survived', 'Pclass']][0:5]

# %%
df12 = df[['Name','Survived', 'Pclass']][5:10]

# %% [markdown]
# # concatenation

# %%
pd.concat([df11,df12],axis=0)
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df11,df12],axis=1)
# Out:
#                                                 Name  Survived  Pclass  \
# 0                            Braund, Mr. Owen Harris       0.0     3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.0     1.0
# 2                             Heikkinen, Miss. Laina       1.0     3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.0     1.0
# 4                           Allen, Mr. William Henry       0.0     3.0
# 5                                                NaN       NaN     NaN
# 6                                                NaN       NaN     NaN
# 7                                                NaN       NaN     NaN
# 8                                                NaN       NaN     NaN
# 9                                                NaN       NaN     NaN
#
#                                                 Name  Survived  Pclass
# 0                                                NaN       NaN     NaN
# ...

# %% [markdown]
# # merge

# %%
data1 = pd.DataFrame(d)

# %%
d
# Out:
# {'key1': (1, 2, 3), 'key2': (4, 5, 6), 'key3': (7, 8, 9)}

# %%
d1={'key1': (1, 2, 3), 'key4': (4, 5, 6), 'key5': (7, 8, 9)}

# %%
data2 = pd.DataFrame(d1)

# %%
data1
# Out:
#    key1  key2  key3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
data2
# Out:
#    key1  key4  key5
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
pd.merge(data1,data2) # default is inner merge
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7     4     7
# 1     2     5     8     5     8
# 2     3     6     9     6     9

# %%
pd.merge(data1,data2,how='left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     7     4     7
# 1     2     5     8     5     8
# 2     3     6     9     6     9

# %% [markdown]
# # join
# - check index

# %%
data1 = pd.DataFrame(d,index=['a','b','c'])

# %%
d1
# Out:
# {'key1': (1, 2, 3), 'key4': (4, 5, 6), 'key5': (7, 8, 9)}

# %%
data2 = pd.DataFrame({'key6': (1, 2, 3), 'key4': (4, 5, 6), 'key5': (7, 8, 9)}
,index=['a','b','i'])

# %%
data1
# Out:
#    key1  key2  key3
# a     1     4     7
# b     2     5     8
# c     3     6     9

# %%
data2
# Out:
#    key6  key4  key5
# a     1     4     7
# b     2     5     8
# i     3     6     9

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     7   1.0   4.0   7.0
# b     2     5     8   2.0   5.0   8.0
# c     3     6     9   NaN   NaN   NaN

# %% [markdown]
# # apply

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - create new column with fare value as INR

# %%
df['Fare_inr']=df['Fare'].apply(lambda x: x*80)

# %%
df['len_name']=df['Name'].apply(lambda x: len(x))

# %%
def inr_conv(x):
    return x*80

# %%
df['Fare_inr1']=df['Fare'].apply(inr_conv)

# %%
def create_flag(x):
    if x<10:
        return "cheap"
    elif x>=10 and x<20:
        return "mid"
    else:
        return "high"

# %%
df['Flag_fare'] = df['Fare'].apply(create_flag)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
