# %% [markdown]
# # Support vector classifier implementation

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_classes=2,
                        n_clusters_per_class=2,n_redundant=0)

# %%
X
# Out:
# array([[-1.54348002,  0.31498898],
#        [ 0.38380793,  1.43885051],
#        [-2.07841059,  0.53418775],
#        ...,
#        [-0.82609915, -0.18456681],
#        [ 1.05961964,  0.46581999],
#        [-1.22438442,  1.07905375]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
y.shape
# Out:
# (1000,)

# %%
X[0]
# Out:
# array([-1.54348002,  0.31498898])

# %%
pd.DataFrame(X)
# Out:
#             0         1
# 0   -1.543480  0.314989
# 1    0.383808  1.438851
# 2   -2.078411  0.534188
# 3    1.057271  0.961850
# 4    1.049601 -0.359169
# ..        ...       ...
# 995  1.775003 -1.087444
# 996 -0.744954  1.026578
# 997 -0.826099 -0.184567
# 998  1.059620  0.465820
# 999 -1.224384  1.079054
#
# [1000 rows x 2 columns]

# %%
sns.scatterplot(x=pd.DataFrame(X)[0],y=pd.DataFrame(X)[1],hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
from sklearn.svm import SVC

# %%
svc=SVC(kernel='linear')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.coef_
# Out:
# array([[-0.0987871,  1.5389658]])

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88       109
#            1       0.83      0.91      0.87        91
#
#     accuracy                           0.88       200
#    macro avg       0.88      0.88      0.87       200
# weighted avg       0.88      0.88      0.88       200
#
# [[92 17]
#  [ 8 83]]
# 0.875

# %% [markdown]
# # Hyperparameter tuning with SVC

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    'C':[0.1,1,10,100,1000],
    'gamma':[1,0.1,0.01,0.001,0.0001],
    'kernel':['linear']
}

# %%
grid = GridSearchCV(svc,param_grid=parameters,refit=True,cv=5,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.881 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.881 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.881 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.881 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.881 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.912 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.894 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.894 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.894 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.894 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.894 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.900 total time=   0.0s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.869 total time=   0.0s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.863 total time=   0.0s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.919 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.900 total time=   0.1s
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.875 total time=   0.1s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.875 total time=   0.1s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.863 total time=   0.1s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.919 total time=   0.2s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.900 total time=   0.2s
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.875 total time=   0.1s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.875 total time=   0.1s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.863 total time=   0.1s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.919 total time=   0.2s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.900 total time=   0.2s
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.875 total time=   0.2s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.875 total time=   0.2s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.863 total time=   0.1s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.919 total time=   0.2s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.900 total time=   0.2s
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.875 total time=   0.1s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.875 total time=   0.2s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.863 total time=   0.2s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.919 total time=   0.2s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.900 total time=   0.2s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.2s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.875 total time=   0.1s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.863 total time=   0.2s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.919 total time=   0.2s
# GridSearchCV(cv=5, estimator=SVC(kernel='linear'),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 1, 'kernel': 'linear'}
